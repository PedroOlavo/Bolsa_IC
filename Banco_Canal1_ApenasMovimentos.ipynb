# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroOlavo/Bolsa_IC/blob/main/Banco_Canal1_ApenasMovimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
n1 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/1Nmar.txt', sep="\s+")
n1.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n2 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/2Nmar.txt', sep="\s+")
n2.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n3 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/3Nmar.txt', sep="\s+")
n3.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n4 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/4Nmar.txt', sep="\s+")
n4.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n5 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/5Nmar.txt', sep="\s+")
n5.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n6 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/6Nmar.txt', sep="\s+")
n6.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n7 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/7Nmar.txt', sep="\s+")
n7.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n8 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/8Nmar.txt', sep="\s+")
n8.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n9 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/9Nmar.txt', sep="\s+")
n9.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n10 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/10Nmar.txt', sep="\s+")
n10.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n11 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/11Nmar.txt', sep="\s+")
n11.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']

# %% [markdown]
# # Corte dos movimentos dos pacientes saudáveis

# %%
n1['C1 - RF'][:5680].plot()

# %%
#movimento do paciente 1
#n11 = n1['C1 - RF'][0:400]
n12 = n1['C1 - RF'][1250:1650]
n13 = n1['C1 - RF'][2550:2950]
n14 = n1['C1 - RF'][3800:4200]
n15 = n1['C1 - RF'][5250:5650]

# %%
n2['C1 - RF'][5400:5800].plot()

# %%
#movimentos paciente 2
#n21 = n2['C1 - RF'][0:400]
n22 = n2['C1 - RF'][1300:1700]
n23 = n2['C1 - RF'][2750:3150]
n24 = n2['C1 - RF'][4100:4500]
n25 = n2['C1 - RF'][5400:5800]

# %%
n3['C1 - RF'][6400:6800].plot()

# %%
#movimentos paciente 3
n31 = n3['C1 - RF'][800:1200]
n32 = n3['C1 - RF'][2300:2700]
n33 = n3['C1 - RF'][3650:4050]
n34 = n3['C1 - RF'][5100:5500]
n35 = n3['C1 - RF'][6400:6800]

# %%
n4['C1 - RF'][6200:6700].plot()

# %%
#movimento canal 4
n41 = n4['C1 - RF'][350:750]
n42 = n4['C1 - RF'][1850:2250]
n43 = n4['C1 - RF'][3400:3800]
n44 = n4['C1 - RF'][4900:5300]
n45 = n4['C1 - RF'][6300:6700]

# %%
n5['C1 - RF'][:6200].plot()
#mostrar esse daqui,ta bem ruim pra tirar amostra

# %%
n6['C1 - RF'][5600:6400].plot()

# %%
#movmentos paciente 6
n61 = n6['C1 - RF'][350:750]
n62 = n6['C1 - RF'][1750:2150]
n63 = n6['C1 - RF'][3000:3400]
n64 = n6['C1 - RF'][4300:4700]
n65 = n6['C1 - RF'][5600:6000]

# %%
n7['C1 - RF'][6800:7600].plot()

# %%
#movimento paciente 7
n71 = n7['C1 - RF'][1300:1700]
n72 = n7['C1 - RF'][2600:3000]
n73 = n7['C1 - RF'][4000:4400]
n74 = n7['C1 - RF'][5350:5750]
n75 = n7['C1 - RF'][6800:7200]

# %%
n8['C1 - RF'][:8200].plot()
#mostrar esse tbm, pois parece que não da pra tirar amostras

# %%
n9['C1 - RF'][:5300].plot()

# %%
#movimentos paciente 9
n91 = n9['C1 - RF'][300:700]
n92 = n9['C1 - RF'][1550:1950]
n93 = n9['C1 - RF'][2800:3200]
n94 = n9['C1 - RF'][4100:4500]

# %%
n10['C1 - RF'][5300:5800].plot()

# %%
#movimentos paciente 10
n101 = n10['C1 - RF'][600:1000]
n102 = n10['C1 - RF'][1800:2200]
n103 = n10['C1 - RF'][3000:3400]
n104 = n10['C1 - RF'][4300:4700]

# %%
n11['C1 - RF'][:].plot()

# %%
x = []
for i in range(401):
  x.append(i)

# %%
movimentos = [n12,n13,n14,n15,n22,n23,n24,n25,n31,n32,n33,n34,n35,
              n41,n42,n43,n44,n45,n61,n62,n63,n64,n65,n71,n72,n73,n74,n75,
              n91,n92,n93,n94,n101,n102,n103,n104]

df = pd.DataFrame()
lista = []
for mov in movimentos:
  mov = mov.to_frame()
  mov = mov.T.reset_index()
  mov.columns = [x]
  lista.append(mov)

df = pd.concat(lista)
df.drop(columns=[0], inplace=True)
df['class'] = 0

# %%
df.head()
# Out:
#         1       2       3       4       5  ...     397     398     399     400 class
# 0 -0.0046 -0.0053 -0.0060 -0.0046 -0.0046  ...  0.0262  0.0352  0.0420  0.0345     0
# 0  0.0067  0.0045 -0.0023 -0.0023 -0.0023  ...  0.0000 -0.0008 -0.0015  0.0015     0
# 0  0.0007 -0.0038 -0.0046 -0.0038 -0.0046  ... -0.0165 -0.0128 -0.0105 -0.0091     0
# 0 -0.0181 -0.0308 -0.0203  0.0030  0.0150  ... -0.0030  0.0007  0.0045  0.0067     0
# 0  0.0015 -0.0015 -0.0053 -0.0030  0.0030  ...  0.0165  0.0202  0.0202  0.0217     0
#
# [5 rows x 401 columns]

# %% [markdown]
# # Corte dos movimentos dos doentes

# %%
n1 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/1Amar.txt', sep="\s+")
n1.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n2 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/2Amar.txt', sep="\s+")
n2.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n3 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/3Amar.txt', sep="\s+")
n3.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n4 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/4Amar.txt', sep="\s+")
n4.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n5 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/5Amar.txt', sep="\s+")
n5.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n6 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/6Amar.txt', sep="\s+")
n6.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n7 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/7Amar.txt', sep="\s+")
n7.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n8 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/8Amar.txt', sep="\s+")
n8.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n9 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/9Amar.txt', sep="\s+")
n9.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']
n10 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/10Amar.txt', sep="\s+")
n10.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']
n11 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/11Amar.txt', sep="\s+")
n11.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']

# %%
n1['C1 - RF'][10000:11000].plot()

# %%
#movimentos paciente doente n1
n12 = n1['C1 - RF'][1250:1650]
n13 = n1['C1 - RF'][4200:4600]
n14 = n1['C1 - RF'][7600:8000]
n15 = n1['C1 - RF'][10600:11000]

# %%
n2['C1 - RF'][:6000].plot()

# %%
n21 = n2['C1 - RF'][200:600]
n22 = n2['C1 - RF'][1300:1700]
n23 = n2['C1 - RF'][3100:3500]
n24 = n2['C1 - RF'][4700:5100]

# %%
n3['C1 - RF'][:6000].plot()

# %%
#movimentos paciente 3 doente
n31 = n3['C1 - RF'][400:800]
n32 = n3['C1 - RF'][1400:1800]
n33 = n3['C1 - RF'][2400:2800]
n34 = n3['C1 - RF'][3200:3600]

# %%
n4['C1 - RF'][:5000].plot()

# %%
#movimentos paciente canal 4
n41 = n4['C1 - RF'][400:800]
n42 = n4['C1 - RF'][1800:2200]
n43 = n4['C1 - RF'][3100:3500]
n44 = n4['C1 - RF'][3800:4200]

# %%
n5['C1 - RF'][:6000].plot()

# %%
n51 = n5['C1 - RF'][200:600]
n52 = n5['C1 - RF'][1200:1600]
n53 = n5['C1 - RF'][2100:2500]
n54 = n5['C1 - RF'][3300:3700]

# %%
n6['C1 - RF'][:5000].plot()

# %%
n61 = n6['C1 - RF'][200:600]
n62 = n6['C1 - RF'][1000:1400]
n63 = n6['C1 - RF'][2000:2400]
n64 = n6['C1 - RF'][3200:3600]

# %%
n7['C1 - RF'][:5000].plot()

# %%
n71 = n7['C1 - RF'][0:400]
n72 = n7['C1 - RF'][600:1000]
n73 = n7['C1 - RF'][2000:2400]
n74 = n7['C1 - RF'][3200:3600]

# %%
n8['C1 - RF'][4000:10000].plot()

# %%
n81 = n8['C1 - RF'][4400:4800]
n82 = n8['C1 - RF'][5900:6300]
n83 = n8['C1 - RF'][7000:7400]
n84 = n8['C1 - RF'][9300:9700]

# %%
n9['C1 - RF'][:8000].plot()

# %%
n91 = n9['C1 - RF'][400:800]
n92 = n9['C1 - RF'][1200:1600]
n93 = n9['C1 - RF'][2900:3300]
n94 = n9['C1 - RF'][5400:5800]

# %%
n10['C1 - RF'][:8000].plot()

# %%
n101 = n10['C1 - RF'][2100:2500]
n102 = n10['C1 - RF'][3400:3800]
n103 = n10['C1 - RF'][5000:5400]
n104 = n10['C1 - RF'][6200:6600]

# %%
n11['C1 - RF'][:8000].plot()

# %%
n111 = n11['C1 - RF'][300:700]
n112 = n11['C1 - RF'][1300:1700]
n113 = n11['C1 - RF'][3100:3500]
n114 = n11['C1 - RF'][6100:6500]

# %%
x = []

for i in range(401):
  x.append(i)


movimentos_d = [n12,n13,n14,n15,n21,n22,n23,n24,n31,n32,n33,n34,
              n41,n42,n43,n44,n51,n52,n53,n54,n61,n62,n63,n64,
              n71,n72,n73,n74,n81,n82,n83,n84,n91,n92,n93,n94,
              n101,n102,n103,n104,n111,n112,n113,n114]

df2 = pd.DataFrame()
lista2 = []
for mov in movimentos_d:
  mov = mov.to_frame()
  mov = mov.T.reset_index()
  mov.columns = [x]
  lista2.append(mov)

df2 = pd.concat(lista2)
df2.drop(columns=[0], inplace=True)
df2['class'] = 1

# %%
df2.head()
# Out:
#         1       2       3       4       5  ...     397     398     399     400 class
# 0  0.0067  0.0052  0.0052  0.0030 -0.0030  ... -0.0990 -0.0945 -0.0893 -0.0856     1
# 0  0.0007 -0.0030 -0.0030 -0.0038 -0.0053  ... -0.0068 -0.0046 -0.0008  0.0000     1
# 0  0.0015  0.0022  0.0030  0.0015  0.0015  ... -0.0593 -0.0503 -0.0413 -0.0308     1
# 0  0.0052  0.0112  0.0142  0.0187  0.0202  ... -0.0323 -0.0480 -0.0608 -0.0653     1
# 0  0.0495  0.0480  0.0465  0.0465  0.0375  ... -0.0278 -0.0240 -0.0195 -0.0181     1
#
# [5 rows x 401 columns]

# %%
ndf = pd.DataFrame()
ndf = pd.concat([df,df2])

# %%
banco_movimentos_canal1 = ndf.to_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/banco_movimentos_canal1')
