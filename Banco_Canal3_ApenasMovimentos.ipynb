# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroOlavo/Bolsa_IC/blob/main/Banco_Canal3_ApenasMovimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
n1 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/1Nmar.txt', sep="\s+")
n1.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n2 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/2Nmar.txt', sep="\s+")
n2.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n3 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/3Nmar.txt', sep="\s+")
n3.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n4 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/4Nmar.txt', sep="\s+")
n4.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n5 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/5Nmar.txt', sep="\s+")
n5.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n6 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/6Nmar.txt', sep="\s+")
n6.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n7 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/7Nmar.txt', sep="\s+")
n7.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n8 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/8Nmar.txt', sep="\s+")
n8.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n9 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/9Nmar.txt', sep="\s+")
n9.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n10 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/10Nmar.txt', sep="\s+")
n10.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n11 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/11Nmar.txt', sep="\s+")
n11.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']

# %% [markdown]
# # Cortes dos movimentos dos pacientes saudaveis

# %%
n1['C3 - VM'][4500:5200].plot()

# %%
#movimentos paciente 1
n12 = n1['C3 - VM'][4600:5000]
n13 = n1['C3 - VM'][1200:1600]
n14 = n1['C3 - VM'][2000:2400]
n15 = n1['C3 - VM'][3400:3800]

# %%
n2['C3 - VM'][4600:6000].plot()

# %%
#movimentos paciente 2
n21 = n2['C3 - VM'][1200:1600]
n22 = n2['C3 - VM'][2700:3100]
n23 = n2['C3 - VM'][4100:4500]
n24 = n2['C3 - VM'][4900:5300]

# %%
n3['C3 - VM'][3400:4800].plot()

# %%
#movimentos paciente 3
n31 = n3['C3 - VM'][250:650]
n32 = n3['C3 - VM'][800:1200]
n33 = n3['C3 - VM'][2250:2650]
n34 = n3['C3 - VM'][3600:4000]

# %%
n4['C3 - VM'][4500:5200].plot()

# %%
#movimentos paciente 4
n41 = n4['C3 - VM'][400:800]
n42 = n4['C3 - VM'][1800:2200]
n43 = n4['C3 - VM'][3350:3750]
n44 = n4['C3 - VM'][4750:5150]

# %%
n5['C3 - VM'][5600:6800].plot()

# %%
#movimentos paciente 5
n51 = n5['C3 - VM'][1800:2200]
n52 = n5['C3 - VM'][3200:3600]
n53 = n5['C3 - VM'][4400:4800]
n54 = n5['C3 - VM'][6100:6500]

# %%
n6['C3 - VM'][4000:4800].plot()

# %%
#movimentos paciente 6
n61 = n6['C3 - VM'][350:750]
n62 = n6['C3 - VM'][1750:2150]
n63 = n6['C3 - VM'][3000:3400]
n64 = n6['C3 - VM'][4300:4700]

# %%
n7['C3 - VM'][6700:7900].plot()

# %%
#movimentos paciente 7
n71 = n7['C3 - VM'][50:450]
n72 = n7['C3 - VM'][1590:1990]
n73 = n7['C3 - VM'][3000:3400]
n74 = n7['C3 - VM'][7350:7750]

# %%
n8['C3 - VM'][6200:].plot()

# %%
#movimentos paciente 8
n81 = n8['C3 - VM'][2600:3000]
n82 = n8['C3 - VM'][4100:4500]

# %%
n9['C3 - VM'][4100:5100].plot()

# %%
#movimentos paciente 9
n91 = n9['C3 - VM'][250:650]
n92 = n9['C3 - VM'][1600:2000]
n93 = n9['C3 - VM'][2800:3200]
n94 = n9['C3 - VM'][4200:4600]

# %%
n10['C3 - VM'][3600:5000].plot()

# %%
#movimentos paciente 10
n101 = n10['C3 - VM'][600:1000]
n102 = n10['C3 - VM'][1800:2200]
n103 = n10['C3 - VM'][2950:3350]
n104 = n10['C3 - VM'][4200:4600]

# %%
n11['C3 - VM'][3000:4400].plot()

# %%
#movimentos paciente 11
n111 = n11['C3 - VM'][350:750]
n112 = n11['C3 - VM'][1980:2380]
n113 = n11['C3 - VM'][2600:3000]
n114 = n11['C3 - VM'][3700:4100]

# %%
x = []
for i in range(401):
  x.append(i)

movimentos = [n12,n13,n14,n15,n21,n22,n23,n24,n24,n31,n32,n33,n34,n41,
              n42,n43,n44,n51,n52,n53,n54,n61,n62,n63,n64,n71,n72,n73,n74,
              n81,n82,n91,n92,n93,n94,n101,n102,n103,n104,n111,n112,n113,n114]

df = pd.DataFrame()
lista = []
for mov in movimentos:
  mov = mov.to_frame()
  mov = mov.T.reset_index()
  mov.columns = [x]
  lista.append(mov)

df = pd.concat(lista)
df.drop(columns=[0], inplace=True)
df['class'] = 0

# %%
df.head()
# Out:
#         1       2       3       4       5  ...     397     398     399     400 class
# 0 -0.0593 -0.0465 -0.0383 -0.0346 -0.0405  ...  0.0172  0.0135  0.0097  0.0067     0
# 0  0.0150  0.0180  0.0165  0.0142  0.0067  ...  0.0015  0.0015  0.0105  0.0157     0
# 0  0.0097  0.0030  0.0030  0.0030  0.0075  ... -0.0008  0.0037  0.0105  0.0127     0
# 0 -0.0053 -0.0091 -0.0105 -0.0091 -0.0158  ...  0.0187  0.0127  0.0120  0.0127     0
# 0  0.0405  0.0367  0.0375  0.0405  0.0420  ...  0.0352  0.0465  0.0465  0.0420     0
#
# [5 rows x 401 columns]

# %% [markdown]
# # Cortes pacientes doentes

# %%
n1 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/1Amar.txt', sep="\s+")
n1.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n2 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/2Amar.txt', sep="\s+")
n2.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n3 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/3Amar.txt', sep="\s+")
n3.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n4 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/4Amar.txt', sep="\s+")
n4.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n5 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/5Amar.txt', sep="\s+")
n5.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n6 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/6Amar.txt', sep="\s+")
n6.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n7 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/7Amar.txt', sep="\s+")
n7.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n8 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/8Amar.txt', sep="\s+")
n8.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n9 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/9Amar.txt', sep="\s+")
n9.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']
n10 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/10Amar.txt', sep="\s+")
n10.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']
n11 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/11Amar.txt', sep="\s+")
n11.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']

# %%
n1['C3 - VM'][8500:10000].plot()

# %%
#movimentos paciente 1
n12 = n1['C3 - VM'][0:400]
n13 = n1['C3 - VM'][1350:1750]
n14 = n1['C3 - VM'][2750:3150]
n15 = n1['C3 - VM'][7700:8100]
n16 = n1['C3 - VM'][9150:9550]

# %%
n2['C3 - VM'][7000:9000].plot()

# %%
#movimentos paciente 2
n21 = n2['C3 - VM'][250:650]
n22 = n2['C3 - VM'][1350:1750]
n23 = n2['C3 - VM'][2450:2850]
n24 = n2['C3 - VM'][4800:5200]
n25 = n2['C3 - VM'][7200:7600]

# %%
n3['C3 - VM'][7000:9000].plot()

# %%
#movimentos paciente 3
n31 = n3['C3 - VM'][1600:2000]
n32 = n3['C3 - VM'][3000:3400]
n33 = n3['C3 - VM'][4400:4800]
n34 = n3['C3 - VM'][7300:7700]

# %%
n4['C3 - VM'][10700:12000].plot()

# %%
#movimentos paciente 4
n41 = n4['C3 - VM'][950:1350]
n42 = n4['C3 - VM'][2400:2800]
n43 = n4['C3 - VM'][3700:4100]
n44 = n4['C3 - VM'][10850:11250]

# %%
n5['C3 - VM'][5200:7800].plot()

# %%
#movimentos paciente 5
n51 = n5['C3 - VM'][1900:2300]
n52 = n5['C3 - VM'][3200:3600]
n53 = n5['C3 - VM'][4400:4800]
n54 = n5['C3 - VM'][5600:6000]

# %%
n6['C3 - VM'][3000:4500].plot()

# %%
#movimentos paciente 6
n61 = n6['C3 - VM'][200:600]
n62 = n6['C3 - VM'][1600:2000]
n63 = n6['C3 - VM'][3000:3400]
n64 = n6['C3 - VM'][4100:4500]

# %%
n7['C3 - VM'][2200:4000].plot()

# %%
#movimentos paciente 7
n71 = n7['C3 - VM'][0:400]
n72 = n7['C3 - VM'][1200:1600]
n73 = n7['C3 - VM'][2400:2800]
n74 = n7['C3 - VM'][3600:4000]

# %%
n8['C3 - VM'][6500:8000].plot()

# %%
#movimentos paciente 8
n81 = n8['C3 - VM'][2900:3300]
n82 = n8['C3 - VM'][3750:4150]
n83 = n8['C3 - VM'][6650:7050]
n84 = n8['C3 - VM'][5780:6180]

# %%
n9['C3 - VM'][4500:6000].plot()

# %%
#movimentos paciente 9
n91 = n9['C3 - VM'][800:1200]
n92 = n9['C3 - VM'][2800:3200]
n93 = n9['C3 - VM'][4000:4400]
n94 = n9['C3 - VM'][5200:5600]

# %%
n10['C3 - VM'][5000:6500].plot()

# %%
#movimentos paciente 10
n101 = n10['C3 - VM'][750:1150]
n102 = n10['C3 - VM'][2100:2500]
n103 = n10['C3 - VM'][3300:3700]
n104 = n10['C3 - VM'][5900:6300]

# %%
n11['C3 - VM'][7000:8200].plot()

# %%
#movimentos paciente 11
n111 = n11['C3 - VM'][500:900]
n112 = n11['C3 - VM'][2150:2550]
n133 = n11['C3 - VM'][5100:5500]
n114 = n11['C3 - VM'][7800:8200]

# %%
movimentos_d = [n12,n13,n14,n15,n21,n22,n23,n24,n25,n31,n32,n33,n34,
              n41,n42,n43,n44,n51,n52,n53,n54,n61,n62,n63,n64,
              n71,n72,n73,n74,n81,n82,n83,n84,n91,n92,n93,n94,
              n101,n102,n103,n104,n111,n112,n113,n114]

df2 = pd.DataFrame()
lista2 = []
for mov in movimentos_d:
  mov = mov.to_frame()
  mov = mov.T.reset_index()
  mov.columns = [x]
  lista2.append(mov)

df2 = pd.concat(lista2)
df2.drop(columns=[0], inplace=True)
df2['class'] = 1

# %%
ndf = pd.DataFrame()
ndf = pd.concat([df,df2])

banco_movimentos_canal3 = ndf.to_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/banco_movimentos_canal3')
