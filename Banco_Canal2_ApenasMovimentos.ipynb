# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroOlavo/Bolsa_IC/blob/main/Banco_Canal2_ApenasMovimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
n1 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/1Nmar.txt', sep="\s+")
n1.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n2 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/2Nmar.txt', sep="\s+")
n2.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n3 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/3Nmar.txt', sep="\s+")
n3.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n4 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/4Nmar.txt', sep="\s+")
n4.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n5 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/5Nmar.txt', sep="\s+")
n5.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n6 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/6Nmar.txt', sep="\s+")
n6.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n7 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/7Nmar.txt', sep="\s+")
n7.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n8 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/8Nmar.txt', sep="\s+")
n8.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n9 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/9Nmar.txt', sep="\s+")
n9.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n10 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/10Nmar.txt', sep="\s+")
n10.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n11 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/11Nmar.txt', sep="\s+")
n11.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']

# %% [markdown]
# # Cortes dos movimentos dos pacientes saudáveis

# %%
n1['C2 - VF'][5000:5600].plot()

# %%
#movimentos paciente 1
n12 = n1['C2 - VF'][0:400]
n13 = n1['C2 - VF'][1200:1600]
n14 = n1['C2 - VF'][2400:2800]
n15 = n1['C2 - VF'][4950:5350]

# %%
n2['C2 - VF'][0:400].plot()

# %%
#movimentos paciente 2
n21 = n2['C2 - VF'][0:400]
#n22 = n2['C2 - VF'][800:1200]
#n23 = n2['C2 - VF']
#n24 = n2['C2 - VF']

# %%
n3['C2 - VF'][6000:].plot()

# %%
#movimentos paciente 3
n31 = n3['C2 - VF'][100:500]
n32 = n3['C2 - VF'][850:1250]
n33 = n3['C2 - VF'][1600:2000]
n34 = n3['C2 - VF'][29000:3300]
n35 = n3['C2 - VF'][6000:6400]

# %%
n4['C2 - VF'][2400:3100].plot()

# %%
#movimentos paciente 4
n41 = n4['C2 - VF'][200:600]
n42 = n4['C2 - VF'][900:1300]
n43 = n4['C2 - VF'][1800:2200]
n44 = n4['C2 - VF'][2600:3000]

# %%
n5['C2 - VF'][4100:4800].plot()

# %%
#movimentos canal 5
n51 = n5['C2 - VF'][400:800]
n52 = n5['C2 - VF'][1800:2200]
n53 = n5['C2 - VF'][3000:3400]
n54 = n5['C2 - VF'][4250:4650]

# %%
n6['C2 - VF'][6300:7200].plot()

# %%
#movimentos paciente 6
n61 = n6['C2 - VF'][300:700]
n62 = n6['C2 - VF'][2900:3300]
n63 = n6['C2 - VF'][4200:4600]
n64 = n6['C2 - VF'][6450:6850]

# %%
n7['C2 - VF'][7000:].plot()

# %%
#movimentos paciente 7
n71 = n7['C2 - VF'][1400:1800]
n72 = n7['C2 - VF'][2800:3200]
n73 = n7['C2 - VF'][4400:4800]
n74 = n7['C2 - VF'][7150:7550]

# %%
n8['C2 - VF'][7500:8300].plot()

# %%
#movimentos paciente 8
n81 = n8['C2 - VF'][350:750]
n82 = n8['C2 - VF'][3400:3800]
n83 = n8['C2 - VF'][6400:6800]
n84 = n8['C2 - VF'][8000:8400]

# %%
n9['C2 - VF'][3900:4800].plot()

# %%
#movimentos paciente 9
n91 = n9['C2 - VF'][150:550]
n92 = n9['C2 - VF'][1450:1850]
n93 = n9['C2 - VF'][2700:3100]
n94 = n9['C2 - VF'][4000:4400]

# %%
n10['C2 - VF'][4000:4800].plot()

# %%
#movimentos paciente 10
n101 = n10['C2 - VF'][550:950]
n102 = n10['C2 - VF'][1800:2200]
n103 = n10['C2 - VF'][2950:3350]
n104 = n10['C2 - VF'][4200:4600]

# %%
n11['C2 - VF'][3600:4400].plot()

# %%
#movimentos paciente 11
n111 = n11['C2 - VF'][200:600]
n112 = n11['C2 - VF'][1400:1800]
n113 = n11['C2 - VF'][2500:2900]
n114 = n11['C2 - VF'][3600:4000]

# %%
x = []
for i in range(401):
  x.append(i)

movimentos = [n12, n13, n14, n15, n21, n31, n41, n42, n43, n44,
              n51, n52, n53, n54, n61, n62, n63, n64, n71, n72, n73, n74, n81,
              n82, n83, n84, n91, n92, n93, n94, n101, n102, n103, n104,
              n111, n112, n113, n114]

df = pd.DataFrame()
lista = []
for mov in movimentos:
  mov = mov.to_frame()
  mov = mov.T.reset_index()
  mov.columns = [x]
  lista.append(mov)

df = pd.concat(lista)
df.drop(columns=[0], inplace=True)
df['class'] = 0

# %% [markdown]
# # Movimento pacientes doentes

# %%
n1 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/1Amar.txt', sep="\s+")
n1.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n2 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/2Amar.txt', sep="\s+")
n2.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n3 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/3Amar.txt', sep="\s+")
n3.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n4 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/4Amar.txt', sep="\s+")
n4.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n5 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/5Amar.txt', sep="\s+")
n5.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n6 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/6Amar.txt', sep="\s+")
n6.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n7 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/7Amar.txt', sep="\s+")
n7.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n8 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/8Amar.txt', sep="\s+")
n8.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX']
n9 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/9Amar.txt', sep="\s+")
n9.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']
n10 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/10Amar.txt', sep="\s+")
n10.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']
n11 = pd.read_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/11Amar.txt', sep="\s+")
n11.columns=['C1 - RF', 'C2 - VF', 'C3 - VM', 'C4 - ST', 'C5 - FX', 'A']

# %%
n1['C2 - VF'][5200:6200].plot()

# %%
#movimento paciente 1
n12 = n1['C2 - VF'][1350:1750]
n13 = n1['C2 - VF'][2800:3200]
n14 = n1['C2 - VF'][4200:4600]
n15 = n1['C2 - VF'][5700:6100]

# %%
n2['C2 - VF'][3600:4700].plot()

# %%
#movimentos paciente 2
n21 = n2['C2 - VF'][600:1000]
n22 = n2['C2 - VF'][1700:2100]
n23 = n2['C2 - VF'][2800:3200]
n24 = n2['C2 - VF'][3900:4300]

# %%
n3['C2 - VF'][4800:6000].plot()

# %%
#movimentos paciente 3
n31 = n3['C2 - VF'][1600:2000]
n32 = n3['C2 - VF'][2100:2500]
n33 = n3['C2 - VF'][3800:4200]
n34 = n3['C2 - VF'][5050:5450]

# %%
n4['C2 - VF'][7900:8600].plot()

# %%
#movimentos paciente 4
n41 = n4['C2 - VF'][4600:5000]
n42 = n4['C2 - VF'][3450:3850]
n43 = n4['C2 - VF'][6500:6900]
n44 = n4['C2 - VF'][8000:8400]

# %%
n5['C2 - VF'][9100:10000].plot()

# %%
#movimentos paciente 5
n51 = n5['C2 - VF'][1950:2350]
n52 = n5['C2 - VF'][3100:3500]
n53 = n5['C2 - VF'][6000:6400]
n54 = n5['C2 - VF'][9050:9450]

# %%
n6['C2 - VF'][7000:8500].plot()

# %%
#movimentos paciente 6
n61 = n6['C2 - VF'][2100:2500]
n62 = n6['C2 - VF'][3250:3650]
n63 = n6['C2 - VF'][5600:6000]
n64 = n6['C2 - VF'][7600:8000]

# %%
n7['C2 - VF'][4800:5500].plot()

# %%
#movimentos paciente 7
n71 = n7['C2 - VF'][1200:1600]
n72 = n7['C2 - VF'][2400:2800]
n73 = n7['C2 - VF'][3600:4000]
n74 = n7['C2 - VF'][5000:5400]

# %%
n8['C2 - VF'][5000:6400].plot()

# %%
#movimentos paciente 8
n81 = n8['C2 - VF'][1800:2200]
n82 = n8['C2 - VF'][2600:3000]
n83 = n8['C2 - VF'][4100:4500]
n84 = n8['C2 - VF'][5000:5400]

# %%
n9['C2 - VF'][5000:6500].plot()

# %%
#movimentos paciente 9
n91 = n9['C2 - VF'][800:1200]
n92 = n9['C2 - VF'][2900:3300]
n93 = n9['C2 - VF'][4000:4400]
n94 = n9['C2 - VF'][5000:5400]

# %%
n10['C2 - VF'][5000:6500].plot()

# %%
#movimento paciente 10
n101 = n10['C2 - VF'][900:1300]
n102 = n10['C2 - VF'][2000:2400]
n103 = n10['C2 - VF'][4600:5000]
n104 = n10['C2 - VF'][5200:5600]

# %%
n11['C2 - VF'][6000:8000].plot()

# %%
#movmentos paciente 11
n111 = n11['C2 - VF'][100:500]
n112 = n11['C2 - VF'][3700:4100]
n113 = n11['C2 - VF'][4400:4800]
n114 = n11['C2 - VF'][6000:6400]

# %%
x = []

for i in range(401):
  x.append(i)


movimentos_d = [n12,n13,n14,n15,n21,n22,n23,n24,n31,n32,n33,n34,n41,n42,n43,n44,
                n51,n52,n53,n54,n61,n62,n63,n64,n71,n72,n73,n74,n81,n82,n83,n84,
                n91,n92,n93,n94,n101,n102,n103,n104,n111,n112,n113,n114]

df2 = pd.DataFrame()
lista2 = []
for mov in movimentos_d:
  mov = mov.to_frame()
  mov = mov.T.reset_index()
  mov.columns = [x]
  lista2.append(mov)

df2 = pd.concat(lista2)
df2.drop(columns=[0], inplace=True)
df2['class'] = 1

# %%
ndf = pd.DataFrame()
ndf = pd.concat([df,df2])

# %%
banco_movimentos_canal2 = ndf.to_csv('/content/drive/MyDrive/BancodeDadosIC - Joelho/banco_movimentos_canal2')
